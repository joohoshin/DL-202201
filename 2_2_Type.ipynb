# %% [markdown]
# # Input
# * input() 명령을 사용하면 컴퓨터에 값을 입력할 수 있습니다.
# * 입력받은 값은 문자로 저장됩니다.

# %%
input()
# Out:
# 10
# '10'

# %%
id = input('id를 입력하세요: ')
# Out:
# id를 입력하세요: abc

# %%
print(id)
# Out:
# abc

# %% [markdown]
# # Data Type
# * input으로 저장된 값은 문자로 저장이 되므로 문자를 숫자로 바꾸어야 계산이 됩니다.
# * str(): 문자로 변경합니다. string의 약자입니다.
# * int(): 정수로 변경합니다. integer의 약자입니다.
# * float(): 실수로 변경합니다.
# * type() 명령을 통해 변수나 값의 데이터 타입을 확인할 수 있습니다.

# %%
키 = input('당신의 키는 몇 cm 입니까? ')
# Out:
# 당신의 키는 몇 cm 입니까? 165

# %%
키
# Out:
# '165'

# %%
type(키)
# Out:
# str

# %%
키 + '3'
# Out:
# '1653'

# %% [markdown]
# * 숫자 연산을 하려면 문자인 입력값을 정수나 실수로 변경을 해야합니다.

# %%
평균키 = 175
차이 = float(키) - 평균키
print('당신은 평균보다 {}cm 큽니다.'.format(차이))
# Out:
# 당신은 평균보다 -10.0cm 큽니다.

# %% [markdown]
# # 주석
# * 작성한 코드에 설명을 달기 위해서는 실행하지 않게 하는 것이 필요합니다.
# * Sharp 기호 뒤의 적힌 부분은 실행되지 않습니다.

# %%
#print('hello')
print('good-bye')
# Out:
# good-bye

# %% [markdown]
# * 여러 줄 주석은 ''' 또는 """를 사용합니다.

# %%
'''
print(10)
print(100)
'''
print(1000)
# Out:
# 1000

# %% [markdown]
# # 활용

# %%
id = input('id를 입력하세요: ')
pw = input('비밀번호를 입력하세요: ')
print('{}님 반갑습니다.'.format(id))
print()  #빈줄 삽입
수입 = input('이번달 수입은 얼마인가요? (만원) ')
지난달 = 1000
print(f'{id}님 수입이 {int(수입)-지난달}만원이 증가하였습니다.') #입력값을 숫자로 변경
# Out:
# id를 입력하세요: abcd
# 비밀번호를 입력하세요: 1234
# abcd님 반갑습니다.
#
# 이번달 수입은 얼마인가요? (만원) 2000
# abcd님 수입이 1000만원이 증가하였습니다.
