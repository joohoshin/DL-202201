# %% [markdown]
# 여러 Feature를 사용해서 예측해봅시다
#
# https://www.tensorflow.org/tutorials/structured_data/time_series

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
import pandas_datareader.data as web

df = web.DataReader('005930', 'naver', start='2010-01-01', end='2020-12-31')

# %%
df
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2010-01-04  16060  16180  16000  16180    239271
# 2010-01-05  16520  16580  16300  16440    559219
# 2010-01-06  16580  16820  16520  16820    459755
# 2010-01-07  16820  16820  16260  16260    443237
# 2010-01-08  16400  16420  16120  16420    295798
# ...           ...    ...    ...    ...       ...
# 2020-12-23  72400  74000  72300  73900  19411326
# 2020-12-24  74100  78800  74000  77800  32502870
# 2020-12-28  79000  80100  78200  78700  40085044
# 2020-12-29  78800  78900  77300  78300  30339449
# 2020-12-30  77400  81300  77300  81000  29417421
#
# [2714 rows x 5 columns]

# %%
df.dtypes
# Out:
# Open      object
# High      object
# Low       object
# Close     object
# Volume    object
# dtype: object

# %%
import pandas as pd
df=df.apply(pd.to_numeric)

# %%
df.dtypes
# Out:
# Open      int64
# High      int64
# Low       int64
# Close     int64
# Volume    int64
# dtype: object

# %%
df.Close.plot()

# %%
TEST_SIZE = 300

train = df[:-TEST_SIZE]
test = df[-TEST_SIZE:]

# %%
import numpy as np
window_size = 20
pred_size = 5

inputs = []
targets = []
for i in range(len(train) - window_size-pred_size):
    inputs.append(np.array(train[i:i+window_size]))
    targets.append(np.array(train.Close[i+window_size:i+window_size+pred_size]))

# %%
inputs[0]
# Out:
# array([[ 16060,  16180,  16000,  16180, 239271],
#        [ 16520,  16580,  16300,  16440, 559219],
#        [ 16580,  16820,  16520,  16820, 459755],
#        [ 16820,  16820,  16260,  16260, 443237],
#        [ 16400,  16420,  16120,  16420, 295798],
#        [ 16420,  16460,  15940,  15940, 398901],
#        [ 15940,  16180,  15900,  16180, 384460],
#        [ 16100,  16119,  15940,  15940, 267619],
#        [ 16120,  16620,  16000,  16540, 532705],
#        [ 16640,  16860,  16580,  16840, 398401],
#        [ 16800,  16920,  16560,  16860, 261691],
#        [ 17000,  17000,  16440,  16460, 241308],
#        [ 16460,  16740,  16460,  16680, 384306],
#        [ 16400,  17000,  16400,  17000, 340148],
#        [ 16800,  16900,  16360,  16500, 470536],
#        [ 16320,  16960,  16300,  16840, 412797],
#        [ 16920,  16920,  16240,  16300, 375210],
#        [ 16300,  16340,  16000,  16000, 370760],
#        [ 16160,  16300,  16060,  16160, 276614],
#        [ 16000,  16019,  15600,  15680, 457285]])

# %%
targets[0]
# Out:
# array([15540, 15440, 15540, 15520, 15000])

# %%
df.head(30)
# Out:
#              Open   High    Low  Close  Volume
# Date
# 2010-01-04  16060  16180  16000  16180  239271
# 2010-01-05  16520  16580  16300  16440  559219
# 2010-01-06  16580  16820  16520  16820  459755
# 2010-01-07  16820  16820  16260  16260  443237
# 2010-01-08  16400  16420  16120  16420  295798
# 2010-01-11  16420  16460  15940  15940  398901
# 2010-01-12  15940  16180  15900  16180  384460
# 2010-01-13  16100  16119  15940  15940  267619
# 2010-01-14  16120  16620  16000  16540  532705
# 2010-01-15  16640  16860  16580  16840  398401
# 2010-01-18  16800  16920  16560  16860  261691
# 2010-01-19  17000  17000  16440  16460  241308
# 2010-01-20  16460  16740  16460  16680  384306
# 2010-01-21  16400  17000  16400  17000  340148
# 2010-01-22  16800  16900  16360  16500  470536
# 2010-01-25  16320  16960  16300  16840  412797
# 2010-01-26  16920  16920  16240  16300  375210
# 2010-01-27  16300  16340  16000  16000  370760
# 2010-01-28  16160  16300  16060  16160  276614
# 2010-01-29  16000  16019  15600  15680  457285
# 2010-02-01  15679  15700  15300  15540  501042
# 2010-02-02  15800  15800  15400  15440  393803
# 2010-02-03  15640  15700  15360  15540  330235
# 2010-02-04  15500  15660  15440  15520  239799
# 2010-02-05  15160  15220  14940  15000  515034
# 2010-02-08  14940  15080  14820  14960  439608
# 2010-02-09  14959  15220  14840  15220  337459
# 2010-02-10  15260  15280  15039  15100  263846
# 2010-02-11  15140  15300  15120  15260  265050
# 2010-02-12  15340  15340  14900  15000  458574

# %%
inputs = np.array(inputs)
targets = np.array(targets)

# %%
print(inputs.shape)
print(targets.shape)
# Out:
# (2389, 20, 5)
# (2389, 5)

# %%
window_size = 20
pred_size = 5

test_inputs = []
test_targets = []
for i in range(len(test) - window_size - pred_size):
    test_inputs.append(np.array(test[i:i+window_size]))
    test_targets.append(np.array(test.Close[i+window_size:i+window_size+pred_size]))
test_inputs=np.array(test_inputs)
test_targets = np.array(test_targets)

# %%
print(inputs.shape)
print(targets.shape)
print(test_inputs.shape)
print(test_targets.shape)
# Out:
# (2389, 20, 5)
# (2389, 5)
# (275, 20, 5)
# (275, 5)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

model = tf.keras.Sequential()
model.add(layers.SimpleRNN(20, 
                           input_shape=(20,5),
                           activation='relu', 
                           return_sequences=False)
          )

model.add(layers.Dense(5))
model.add(layers.Reshape([5,1]))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn (SimpleRNN)       (None, 20)                520
# _________________________________________________________________
# dense (Dense)                (None, 5)                 105
# _________________________________________________________________
# reshape (Reshape)            (None, 5, 1)              0
# =================================================================
# Total params: 625
# Trainable params: 625
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

history = model.fit(inputs, targets, 
                                    epochs=30, 
                                    batch_size=32,
                                    validation_data=(test_inputs, test_targets))
# Out:
# Epoch 1/30
# 75/75 [==============================] - 2s 9ms/step - loss: 702805901312.0000 - val_loss: 3385830932480.0000
# Epoch 2/30
# 75/75 [==============================] - 0s 5ms/step - loss: 92583976960.0000 - val_loss: 610310029312.0000
# Epoch 3/30
# 75/75 [==============================] - 0s 5ms/step - loss: 36680876032.0000 - val_loss: 342412197888.0000
# Epoch 4/30
# 75/75 [==============================] - 0s 5ms/step - loss: 23233468416.0000 - val_loss: 258324742144.0000
# Epoch 5/30
# 75/75 [==============================] - 0s 5ms/step - loss: 16628554752.0000 - val_loss: 196232708096.0000
# Epoch 6/30
# 75/75 [==============================] - 0s 5ms/step - loss: 12644335616.0000 - val_loss: 161738817536.0000
# Epoch 7/30
# 75/75 [==============================] - 0s 5ms/step - loss: 10053203968.0000 - val_loss: 138462593024.0000
# Epoch 8/30
# 75/75 [==============================] - 0s 5ms/step - loss: 8482420736.0000 - val_loss: 117832671232.0000
# Epoch 9/30
# 75/75 [==============================] - 0s 5ms/step - loss: 7301222912.0000 - val_loss: 102214926336.0000
# Epoch 10/30
# 75/75 [==============================] - 0s 5ms/step - loss: 6279508480.0000 - val_loss: 96609968128.0000
# Epoch 11/30
# 75/75 [==============================] - 0s 5ms/step - loss: 5584935424.0000 - val_loss: 81347862528.0000
# Epoch 12/30
# 75/75 [==============================] - 0s 5ms/step - loss: 4816481280.0000 - val_loss: 71048200192.0000
# Epoch 13/30
# 75/75 [==============================] - 0s 5ms/step - loss: 4198700288.0000 - val_loss: 61263306752.0000
# Epoch 14/30
# 75/75 [==============================] - 0s 5ms/step - loss: 3733585920.0000 - val_loss: 52545769472.0000
# Epoch 15/30
# 75/75 [==============================] - 0s 5ms/step - loss: 3326979072.0000 - val_loss: 44912041984.0000
# Epoch 16/30
# 75/75 [==============================] - 0s 6ms/step - loss: 2990391808.0000 - val_loss: 39352778752.0000
# Epoch 17/30
# 75/75 [==============================] - 1s 7ms/step - loss: 2649746688.0000 - val_loss: 32449746944.0000
# Epoch 18/30
# 75/75 [==============================] - 0s 5ms/step - loss: 2343920640.0000 - val_loss: 27797073920.0000
# Epoch 19/30
# 75/75 [==============================] - 0s 5ms/step - loss: 2084961024.0000 - val_loss: 23770568704.0000
# Epoch 20/30
# 75/75 [==============================] - 0s 6ms/step - loss: 1892895872.0000 - val_loss: 21843509248.0000
# Epoch 21/30
# 75/75 [==============================] - 0s 6ms/step - loss: 1759265664.0000 - val_loss: 21043222528.0000
# Epoch 22/30
# 75/75 [==============================] - 0s 6ms/step - loss: 1690386560.0000 - val_loss: 16340928512.0000
# Epoch 23/30
# 75/75 [==============================] - 0s 6ms/step - loss: 1549158784.0000 - val_loss: 16469948416.0000
# Epoch 24/30
# 75/75 [==============================] - 0s 6ms/step - loss: 1443488256.0000 - val_loss: 14053041152.0000
# Epoch 25/30
# 75/75 [==============================] - 0s 6ms/step - loss: 1367513088.0000 - val_loss: 13353572352.0000
# Epoch 26/30
# 75/75 [==============================] - 0s 6ms/step - loss: 1284483072.0000 - val_loss: 13186288640.0000
# Epoch 27/30
# 75/75 [==============================] - 0s 5ms/step - loss: 1238724224.0000 - val_loss: 11419123712.0000
# Epoch 28/30
# 75/75 [==============================] - 0s 5ms/step - loss: 1166753024.0000 - val_loss: 11959997440.0000
# Epoch 29/30
# 75/75 [==============================] - 0s 5ms/step - loss: 1122146816.0000 - val_loss: 10586147840.0000
# Epoch 30/30
# 75/75 [==============================] - 0s 5ms/step - loss: 1087823488.0000 - val_loss: 9244073984.0000

# %%
pred = model.predict(test_inputs)

# %%
pred.shape
# Out:
# (275, 5, 1)

# %%
targets.shape
# Out:
# (2389, 5)

# %%
import matplotlib.pyplot as plt

plt.plot(test_targets[0,:], label = 'true')
plt.plot(pred[0,:,0], label = 'prediction')
plt.legend()

# %%
test_inputs.shape
# Out:
# (275, 20, 5)

# %%
import matplotlib.pyplot as plt
plt.plot(test_inputs[0,:,0])
plt.plot(range(20,25),test_targets[0,:], label = 'true', marker='o',linestyle='None')
plt.plot(range(20,25),pred[0,:,0], label = 'prediction', marker='x',linestyle='None')
plt.legend()
