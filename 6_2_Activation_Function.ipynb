# %% [markdown]
# Activation Function
#
# Tensorflow
# https://www.tensorflow.org/api_docs/python/tf/keras/activations

# %%
from google.colab import drive
drive.mount('/g')
# Out:
# Drive already mounted at /g; to attempt to forcibly remount, call drive.mount("/g", force_remount=True).

# %%
from IPython.display import Image
Image(filename='/g/My Drive/Tensorflow AI/wallpaper2you_364318.jpg', width=500)

# %%
import cv2
img = cv2.imread('/g/My Drive/Tensorflow AI/wallpaper2you_364318.jpg',0) # 0은 그레이스케일로 읽기

# %%
img
# Out:
# array([[230, 232, 233, ...,  95,  94,  93],
#        [230, 231, 233, ...,  93,  91,  90],
#        [230, 231, 232, ...,  92,  91,  90],
#        ...,
#        [100,  77,  62, ...,  97,  85,  73],
#        [111,  78,  58, ...,  81,  69,  58],
#        [ 92,  68,  56, ...,  77,  68,  58]], dtype=uint8)

# %%
import matplotlib.pyplot as plt
plt.imshow(img, cmap='gray')

# %%
relu = lambda x: 0 if x<0 else x

# %%
img.max()
# Out:
# 255

# %%
img.min()
# Out:
# 0

# %%
x = img/255-0.5

# %%
import numpy as np
relu_x = np.vectorize(relu)(x)

# %%
relu_x.shape
# Out:
# (1600, 2560)

# %%
plt.imshow(relu_x, cmap='gray')

# %%
plt.imshow(x, cmap='gray')
