# %% [markdown]
# ### 숫자인식은 딥러닝의 가장 기초적인 예제입니다.
#
# 아래의 텐서플로우 공식싸이트의 예제를 참고하세요
#
# https://www.tensorflow.org/tutorials/quickstart/beginner

# %% [markdown]
# 1. 라이브러리 불러오기

# %%
import tensorflow as tf

# %% [markdown]
# 2. 데이터 불러오기

# %%
# 데이터 불러오기
mnist = tf.keras.datasets.mnist   # 학습할 수 있는 주요 데이터셋은 텐서플로우에서 제공하고 있음

(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %% [markdown]
# 3. 데이터 전처리

# %%
# 데이터 표준화: 이미지 파일은 컬러의 경우 RGB에 대해 각각 0~255 정수로 이루어진 배열임
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
type(x_train)
# Out:
# numpy.ndarray

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
y_test.shape
# Out:
# (10000,)

# %% [markdown]
# 4. 모델 만들기

# %%
# 간단한 모델 만들기
# Sequential API를 활용하여 손쉽게 모델을 만들 수 있음

model = tf.keras.models.Sequential([                # 함수의 입력값을 리스트로 여러개의 레이어를 넣은 것임
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

# %% [markdown]
# 5. 모델 컴파일

# %%
# 모델 컴파일하기: 학습과 관련된 설정
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# 6. 모델 학습

# %%
# 모델 학습
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 7s 2ms/step - loss: 1.2324 - accuracy: 0.6787
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5448 - accuracy: 0.8512
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4207 - accuracy: 0.8805
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3707 - accuracy: 0.8933
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3389 - accuracy: 0.9005

# %% [markdown]
# 7. 모델 평가

# %%
# 성과 평가
model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.2905 - accuracy: 0.9175 - 678ms/epoch - 2ms/step
# [0.2904934883117676, 0.9175000190734863]
