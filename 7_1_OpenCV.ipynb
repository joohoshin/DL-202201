# %% [markdown]
# 1. OpenCV를 통해 이미지를 Numpy 배열 형태로 읽어들일 수 있습니다.
#
#     https://opencv.org/
#
#     최근에는 딥러닝 관련 설명 기능 보강되었음
#
#     Opencv로 읽어들이면 RGB가 아닌 BGR 순서로 읽게 됨
#
# 2. PIL(Pillow)도 파이썬 이미지 불러오고 처리하는 라이브러리, 자체 형식으로 읽어들여져서 Numpy로 변환 필요
#
#     https://pillow.readthedocs.io/en/stable/#
#
# --> 실제 프로젝트에서는 OpenCV를 더 많이 사용함 (동영상 처리 등에 유리)

# %%
import cv2

# %%
from google.colab import drive
drive.mount('/g')
# Out:
# Drive already mounted at /g; to attempt to forcibly remount, call drive.mount("/g", force_remount=True).

# %%
image = cv2.imread('/g/My Drive/Tensorflow AI/twice1.png')

# %%
image.shape
# Out:
# (2048, 1365, 3)

# %%
type(image)
# Out:
# numpy.ndarray

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Matplotlib로 이미지 출력 시 색상이 다르게 나옴
#
# matplotlib는 rgb 컬러를 사용

# %%
import matplotlib.pyplot as plt
plt.imshow(image)

# %%
# opencv cvtColor를 통해 변환 가능
image_temp = cv2.cvtColor(image, cv2.COLOR_BGR2RGB )
plt.imshow(image_temp)
